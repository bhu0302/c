# %%
from django.urls import get_resolver
for p in get_resolver().url_patterns:
    print(p)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[2], line 2
#       1 from django.urls import get_resolver
# ----> 2 for p in get_resolver().url_patterns:
#       3     print(p)
#
# File ~\anaconda3\Lib\site-packages\django\urls\resolvers.py:110, in get_resolver(urlconf)
#     108 def get_resolver(urlconf=None):
#     109     if urlconf is None:
# --> 110         urlconf = settings.ROOT_URLCONF
#     111     return _get_cached_resolver(urlconf)
#
# File ~\anaconda3\Lib\site-packages\django\conf\__init__.py:81, in LazySettings.__getattr__(self, name)
#      79 """Return the value of a setting and cache it in self.__dict__."""
#      80 if (_wrapped := self._wrapped) is empty:
# ---> 81     self._setup(name)
#      82     _wrapped = self._wrapped
#      83 val = getattr(_wrapped, name)
#
# ...
